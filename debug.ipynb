# %%
import urllib.parse
import requests
from bs4 import BeautifulSoup, SoupStrainer
from collections import defaultdict
import datetime
from datetime import timedelta

def tours_between_two_dates(start, end, step = timedelta(days = 1)):
    
    date_format = "%Y-%m-%d"
    
    st = datetime.datetime.strptime(start, date_format).date()
    en = datetime.datetime.strptime(end, date_format).date()

    curr = st
    while curr <= en:
        yield curr
        curr += step

def between_two_dates(start, end):
    
    dates = list(tours_between_two_dates(start, end, step = timedelta(days = 1)))
    all_the_dates = [str(j) for j in dates]
    
    return all_the_dates

def get_walk_info(all_the_dates):
    
    base_url = "https://www.walks.com/our-walks/walks-by-date/"

    main = []
    for day in all_the_dates:
        urls = base_url + "?d=" + day
        responses = requests.get(urls)
        soup_strainer = SoupStrainer('div', {"class": "walkrow suspended-walkrow"})
        soups = BeautifulSoup(responses.content, 'html.parser', parse_only = soup_strainer)
        guides = soups.findAll('a', {'class':'guideLink'}, href = True)
        tube = soups.findAll(class_ = "tube")
        description = soups.findAll('div', {'class':'description'})
        time = soups.findAll('div', {'class': 'col-xs-3 time'})


        for index, item in enumerate(soups.findAll('a', {'class':'h4Title'}, href = True)):
            walks = {}
            walks['tour_date'] = day
            walks['tour_time'] = time[index].text.strip()
            walks['tour_name'] = item.text
            walks['tour_desc_short'] = description[index].p.text.strip().replace('\xa0', '')
            walks['meeting_spot'] = tube[index].text
            walks['tour_link'] = item['href']
            walks['guide_name'] = guides[index].text
            walks['guide_link'] = "https://walks.com" + guides[index]['href']

            main.append(walks)
    
    return main  

def get_guide_info():
    
    response = requests.get('https://www.walks.com/guides/')
    soup = BeautifulSoup(response.content, 'html.parser')

    guide = []
    for g in soup.findAll("div", {'class': 'collapse-list-item'}):
        guides = {}
        try:
            guides['guide_name'] = g.h4.text
            guides['guide_link']= "https://walks.com/guides/" + g.a['href']
            guides['guide_description'] = g.p.text

            guide.append(guides)

        except AttributeError:
            continue
    
    return guide

def get_tours(start, end):
    all_the_dates = between_two_dates(start, end)
    walks = get_walk_info(all_the_dates)
    
    return walks

# %%
get_tours('2020-01-01', '2020-01-3')
# Out:
# [{'tour_date': '2020-01-01',
#   'tour_time': '11 am',
#   'tour_name': 'The Tower of London',
#   'tour_desc_short': '“the most important mediaeval fortress in Europe”',
#   'meeting_spot': 'Tower Hill underground station, London (meet by the Tower Hill Tram coffee stand) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/the-tower-of-london-tour-1-1/',
#   'guide_name': 'Brian',
#   'guide_link': 'https://walks.com/guides/#brian'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '11 am',
#   'tour_name': 'Little Venice – the pursuit of pleasure',
#   'tour_desc_short': '“Shaughan was something else with his jokes and songs and obvious knowledge of the area…”',
#   'meeting_spot': 'Warwick Avenue underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/little-venice/',
#   'guide_name': 'Judy',
#   'guide_link': 'https://walks.com/guides/#judy'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '11 am',
#   'tour_name': 'The Inns of Court',
#   'tour_desc_short': '“like a clutch of Oxbridge colleges in the heart of London”',
#   'meeting_spot': 'Holborn underground station, London (main exit, debouches onto Kingsway)',
#   'tour_link': 'https://www.walks.com/our-walks/legal-illegal-london-the-inns-of-court-1/',
#   'guide_name': 'Tom',
#   'guide_link': 'https://walks.com/guides/#tom'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '1.45 pm',
#   'tour_name': 'Chelsea - Riverside Village',
#   'tour_desc_short': '“these gnarled old village lanes and byways are as clamorous with great names as rooks in a wood”',
#   'meeting_spot': 'Sloane Square tube station, London',
#   'tour_link': 'https://www.walks.com/our-walks/chelsea-londons-ancient-riverside-village/',
#   'guide_name': 'Peter G.',
#   'guide_link': 'https://walks.com/guides/#peter-g'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '2 pm',
#   'tour_name': 'Hampstead Village & Heath',
#   'tour_desc_short': '“the jewel in the London Walks crown” The New York Times',
#   'meeting_spot': 'Hampstead Underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/old-hampstead-village-1/',
#   'guide_name': 'Richard III',
#   'guide_link': 'https://walks.com/guides/#richard-iii'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '2.15 pm',
#   'tour_name': 'Old London',
#   'tour_desc_short': '“Secret places and hidden history in a Flash! Bang! Lightning! City of London Highlights Tour”',
#   'meeting_spot': "St. Paul's underground station, London (exit 2)",
#   'tour_link': 'https://www.walks.com/our-walks/old-london-secret-places-hidden-history/',
#   'guide_name': 'Shaughan',
#   'guide_link': 'https://walks.com/guides/#shaughan'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '2.30 pm',
#   'tour_name': 'British Museum Tour',
#   'tour_desc_short': '“Whoever travels without a guide needs 200 years for a 2-hour journey” Rumi',
#   'meeting_spot': 'Russell Square underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/the-british-museum-tour/',
#   'guide_name': 'Karen',
#   'guide_link': 'https://walks.com/guides/#karen'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '2.30 pm',
#   'tour_name': 'THE CROWN',
#   'tour_desc_short': '“several London Walks guides have been inside, met the Queen and Prince Philip. One has a contact who worked on the series…”',
#   'meeting_spot': 'Green Park underground station, London (Green Park exit, by the fountain) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/the-crown/',
#   'guide_name': 'Molly',
#   'guide_link': 'https://walks.com/guides/#molly'},
#  {'tour_date': '2020-01-01',
#   'tour_time': '7.30 pm',
#   'tour_name': 'Jack The Ripper Walking Tour',
#   'tour_desc_short': 'Do the Jack the Ripper Virtual Tour.“In 1888 I was a freak. Today I’m an amateur” — Jack the Ripper',
#   'meeting_spot': 'Tower Hill underground station, London (meet by the Tower Hill Tram coffee stand) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/jack-the-ripper-walking-tour/',
#   'guide_name': 'Shaughan',
#   'guide_link': 'https://walks.com/guides/#shaughan'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '10.45 am',
#   'tour_name': 'Old Mayfair',
#   'tour_desc_short': '“the champagne & caviar of London Walks”',
#   'meeting_spot': 'Green Park underground station, London (north exit, on the corner)',
#   'tour_link': 'https://www.walks.com/our-walks/old-mayfair-the-champagne-caviar-of-london-walks-1/',
#   'guide_name': 'Peter G.',
#   'guide_link': 'https://walks.com/guides/#peter-g'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '10.45 am',
#   'tour_name': 'Undiscovered London, Butlers Wharf and Shad Thames',
#   'tour_desc_short': 'Four words* that make my blood race: “hasn’t yet been discovered.” *Right up there with hidden places, hidden history',
#   'meeting_spot': 'Bermondsey underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/undiscovered-london/',
#   'guide_name': 'Richard III',
#   'guide_link': 'https://walks.com/guides/#richard-iii'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '10.45 am',
#   'tour_name': 'Inside Story – Covent Garden',
#   'tour_desc_short': 'Taking You Inside LONDON',
#   'meeting_spot': 'Covent Garden underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/inside-covent-garden-really-inside/',
#   'guide_name': 'Ann',
#   'guide_link': 'https://walks.com/guides/#ann'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '11 am',
#   'tour_name': 'Beatles Magical Mystery Tour',
#   'tour_desc_short': '“Richard Porter’s personal kinship with John, Paul, George and Ringo makes his tours some of the most popular in the city”, USA Today',
#   'meeting_spot': 'Tottenham Court Road underground station, London (exit 1)',
#   'tour_link': 'https://www.walks.com/our-walks/the-beatles-magical-mystery-tour/',
#   'guide_name': 'Fiona',
#   'guide_link': 'https://walks.com/guides/#fiona'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '11 am',
#   'tour_name': 'The Famous Square Mile',
#   'tour_desc_short': 'The great classic London Walk: explores the very heart of the City – the most historic part of the capital…',
#   'meeting_spot': 'Monument Underground station, London (Fish Street Hill exit)',
#   'tour_link': 'https://www.walks.com/our-walks/the-famous-square-mile-2000-years-of-history-1/',
#   'guide_name': 'Isobel',
#   'guide_link': 'https://walks.com/guides/#isobel'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '2 pm',
#   'tour_name': 'Kensington – Royal Village',
#   'tour_desc_short': 'Whack Covid! Go to Kensington on the Virtual Tour.',
#   'meeting_spot': 'High Street Kensington underground station, London (meet by the Wasabi restaurant at the end of the shopping arcade that links the station with the High Street)) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/old-kensington-londons-royal-village/',
#   'guide_name': 'Adam',
#   'guide_link': 'https://walks.com/guides/#adam'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '2 pm',
#   'tour_name': 'Crime & Punishment',
#   'tour_desc_short': 'London – Prototype of Hell',
#   'meeting_spot': "St. Paul's underground station, London (exit 2)",
#   'tour_link': 'https://www.walks.com/our-walks/crime-punishment-the-city-of-the-gallows/',
#   'guide_name': 'Karen',
#   'guide_link': 'https://walks.com/guides/#karen'},
#  {'tour_date': '2020-01-02',
#   'tour_time': '7.30 pm',
#   'tour_name': 'Jack The Ripper Walking Tour',
#   'tour_desc_short': 'Do the Jack the Ripper Virtual Tour.“In 1888 I was a freak. Today I’m an amateur” — Jack the Ripper',
#   'meeting_spot': 'Tower Hill underground station, London (meet by the Tower Hill Tram coffee stand) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/jack-the-ripper-walking-tour/',
#   'guide_name': 'Richard P',
#   'guide_link': 'https://walks.com/guides/#richard-p'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '10.15 am',
#   'tour_name': 'A Soho Saunter',
#   'tour_desc_short': '“noisy, bawdy, dirty and sexy, and one of the few quarters in London that has kept its character, warts and all”',
#   'meeting_spot': "Leicester Square underground station, London (exit 1, by Wyndham's Theatre)",
#   'tour_link': 'https://www.walks.com/our-walks/a-soho-saunter-top-of-the-morning-to-you/',
#   'guide_name': 'Adam',
#   'guide_link': 'https://walks.com/guides/#adam'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '10.20 am',
#   'tour_name': "Thames Sightseeing, Brunel's River Cruise",
#   'tour_desc_short': '“I have been on several London walks but this was simply the best, with a boat ride thrown in and an amazing surprise at the end!”',
#   'meeting_spot': 'Embankment underground station, London (river exit) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/thames-sightseeing-brunels-river-cruise/',
#   'guide_name': 'Peter G.',
#   'guide_link': 'https://walks.com/guides/#peter-g'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '10.45 am',
#   'tour_name': 'Victoria & Albert Museum',
#   'tour_desc_short': '“it’s not what we see but what we see in it”',
#   'meeting_spot': 'South Kensington underground station, London (meet just beyond the ticket barrier)',
#   'tour_link': 'https://www.walks.com/our-walks/the-victoria-albert-museum-tour-ooh-wow/',
#   'guide_name': 'Richard III',
#   'guide_link': 'https://walks.com/guides/#richard-iii'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '11 am',
#   'tour_name': 'Unexpected London',
#   'tour_desc_short': '“secret places and hidden interiors”',
#   'meeting_spot': 'Temple underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/unexpected-london-secret-places-hidden-interiors/',
#   'guide_name': 'Robert',
#   'guide_link': 'https://walks.com/guides/#robert'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '11 am',
#   'tour_name': 'Hidden London',
#   'tour_desc_short': '“the distillation of a brilliant guide’s vast experience probing the secret places of the world’s most elusive city”',
#   'meeting_spot': 'Monument Underground station, London (Fish Street Hill exit)',
#   'tour_link': 'https://www.walks.com/our-walks/hidden-london/',
#   'guide_name': 'Margaret',
#   'guide_link': 'https://walks.com/guides/#margaret'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2 pm',
#   'tour_name': 'Ahoy! The Mayflower Village',
#   'tour_desc_short': '“this place still looks like – feels like – what it once was”',
#   'meeting_spot': 'Rotherhithe Overground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/lost-village-secret-tunnel-mayflower-brunel/',
#   'guide_name': 'Molly',
#   'guide_link': 'https://walks.com/guides/#molly'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2 pm',
#   'tour_name': "Rock 'n' Roll London",
#   'tour_desc_short': 'Do the Rock n Roll London Virtual Tour. “It rocks!”',
#   'meeting_spot': 'Tottenham Court Road underground station, London (exit 1)',
#   'tour_link': 'https://www.walks.com/our-walks/rock-n-roll-london-the-pub-walk/',
#   'guide_name': 'Alison',
#   'guide_link': 'https://walks.com/guides/#alison'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2 pm',
#   'tour_name': 'In the Footsteps of Sherlock Holmes',
#   'tour_desc_short': 'Grab your deerstalker and magnifying glass,           we’re going sleuthing…',
#   'meeting_spot': 'Embankment underground station, London (Villiers Street exit) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/in-the-footsteps-of-sherlock-holmes/',
#   'guide_name': 'Hilary',
#   'guide_link': 'https://walks.com/guides/#hilary'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2.15 pm',
#   'tour_name': 'The National Gallery',
#   'tour_desc_short': '“You’ve been nailed again, eye-popped. Life has just been adjusted.”',
#   'meeting_spot': 'Embankment underground station, London (Villiers Street exit) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/the-national-gallery-the-best-art-tour-ever/',
#   'guide_name': 'Kim',
#   'guide_link': 'https://walks.com/guides/#kim'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2.30 pm',
#   'tour_name': "Charles Dickens's London",
#   'tour_desc_short': '“a sojourn into a lost city – an Atlantis”',
#   'meeting_spot': 'Embankment Tube, Villiers Street exit | Map',
#   'tour_link': 'https://www.walks.com/our-walks/charles-dickens-london/',
#   'guide_name': 'Shaughan',
#   'guide_link': 'https://walks.com/guides/#shaughan'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '2.30 pm',
#   'tour_name': 'The Old Palace Quarter',
#   'tour_desc_short': '“secret passageways that take you into the 16th-century”',
#   'meeting_spot': 'Green Park underground station, London (Green Park exit, by the fountain) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/the-old-palace-quarter-the-wayback-walk/',
#   'guide_name': 'Robert',
#   'guide_link': 'https://walks.com/guides/#robert'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '7 pm',
#   'tour_name': 'Along the Thames Pub Walk',
#   'tour_desc_short': '“the most exciting walk in London, it does more to interpret the city than anything else, a real skeleton key”',
#   'meeting_spot': 'Blackfriars underground station, London',
#   'tour_link': 'https://www.walks.com/our-walks/the-along-the-thames-pub-walk/',
#   'guide_name': 'Tim',
#   'guide_link': 'https://walks.com/guides/#tim-t'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '7 pm',
#   'tour_name': "Visite Guidée Jack L'Eventreur",
#   'tour_desc_short': 'Read More',
#   'meeting_spot': 'au Métro Tower Hill',
#   'tour_link': 'https://www.walks.com/our-walks/jack-leventreur/',
#   'guide_name': 'Adam',
#   'guide_link': 'https://walks.com/guides/#adam'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '7.30 pm',
#   'tour_name': 'Jack The Ripper Walking Tour',
#   'tour_desc_short': 'Do the Jack the Ripper Virtual Tour.“In 1888 I was a freak. Today I’m an amateur” — Jack the Ripper',
#   'meeting_spot': 'Tower Hill underground station, London (meet by the Tower Hill Tram coffee stand) | Map',
#   'tour_link': 'https://www.walks.com/our-walks/jack-the-ripper-walking-tour/',
#   'guide_name': 'Rex',
#   'guide_link': 'https://walks.com/guides/#rex'},
#  {'tour_date': '2020-01-03',
#   'tour_time': '7.30 pm',
#   'tour_name': 'Chilling Tales from Beyond the Grave',
#   'tour_desc_short': '“the creepiest part of London…                    alleyways so old they’re cobwebbed with time”',
#   'meeting_spot': 'Monument Underground station, London (Fish Street Hill exit)',
#   'tour_link': 'https://www.walks.com/our-walks/haunted-london/',
#   'guide_name': 'Corinna',
#   'guide_link': 'https://walks.com/guides/#corinna'}]
